# %%
import xml.etree.ElementTree as ET

data = open('festivalsXML.xml')
xmlData = data.read()

tree = ET.fromstring(xmlData)
elemList = []

for elem in tree.iter():
    elemList.append(elem.tag)
    
elemList = list(set(elemList))
# Out:
# viewentries
# viewentry
# entrydata
# text
# entrydata
# text
# entrydata
# textlist
# text
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# textlist
# text
# text
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# entrydata
# text
# ...
